# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm_notebook
import time
from datetime import datetime, date
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import re

# %%
df = pd.read_csv(r"C:\Users\Lenovo\數據分析\天下專案\10- Key Metrics.csv")
likes = pd.read_csv(r"C:\Users\Lenovo\數據分析\天下專案\like.csv")

# %%
likes2 = pd.read_csv(r"C:\Users\Lenovo\數據分析\天下專案\like2.csv")

# %%
likes_clean = likes[['已發佈','永久連結','like','comment','share']]
likes2_clean = likes2[['已發佈','永久連結','like','comment','share']]
likes2_clean['month'] = likes2_clean['已發佈'].apply(lambda x: x[:2])
#取原本 "已發佈" 變數的前2個字 
likes2_clean = likes2_clean[likes2_clean['month'] == '10']

# %%
likes2_clean
# Out:
#           已發佈                                               永久連結  like  \
# 0    10/14/20  https://www.facebook.com/cwgroup/posts/1015721...   193
# 1    10/14/20  https://www.facebook.com/cwgroup/posts/1015721...   257
# 2    10/14/20  https://www.facebook.com/cwgroup/posts/1015721...    28
# 3    10/14/20  https://www.facebook.com/cwgroup/posts/1015721...   316
# 4    10/14/20  https://www.facebook.com/cwgroup/posts/1015720...    60
# ..        ...                                                ...   ...
# 449   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    32
# 450   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    22
# 451   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    40
# 452   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    24
# 453   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    39
#
#      comment  share month
# 0       54.0   20.0    10
# 1       15.0   36.0    10
# 2        NaN   10.0    10
# 3       16.0   14.0    10
# 4        1.0    2.0    10
# ..       ...    ...   ...
# 449      NaN    6.0    10
# 450      NaN    5.0    10
# 451      NaN    5.0    10
# 452      2.0    NaN    10
# 453      1.0    4.0    10
#
# [454 rows x 6 columns]

# %%
all_like = likes_clean.append(likes2_clean)
all_like
# Out:
#           已發佈                                               永久連結  like  \
# 0     11/8/20  https://www.facebook.com/cwgroup/posts/1015726...    19
# 1    10/30/20  https://www.facebook.com/cwgroup/posts/1015724...    11
# 2    10/30/20  https://www.facebook.com/cwgroup/posts/1015724...    12
# 3    10/30/20  https://www.facebook.com/cwgroup/posts/1015724...    63
# 4    10/30/20  https://www.facebook.com/cwgroup/posts/1015724...   329
# ..        ...                                                ...   ...
# 449   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    32
# 450   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    22
# 451   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    40
# 452   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    24
# 453   10/1/20  https://www.facebook.com/cwgroup/posts/1015718...    39
#
#      comment  share month
# 0        3.0    NaN   NaN
# 1        NaN    2.0   NaN
# 2        NaN    5.0   NaN
# 3        2.0    7.0   NaN
# 4       16.0   49.0   NaN
# ..       ...    ...   ...
# 449      NaN    6.0    10
# 450      NaN    5.0    10
# 451      NaN    5.0    10
# 452      2.0    NaN    10
# 453      1.0    4.0    10
#
# [954 rows x 6 columns]

# %%
df = df[['永久連結',"Lifetime Post Total Reach"]]
df['永久連結'][0]
# Out:
# nan

# %%
browser = webdriver.Chrome(executable_path = "C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe")
proxy = {
        'https': 'https://91.206.30.218:3128'
    }
header = {
        'User-agent': 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)',
    }
info = pd.DataFrame(columns = ['標題'])
for i in range(1,925):
    browser.get(df['永久連結'][i])
    soup7 = BeautifulSoup(browser.page_source, "html.parser") 
    blocks = soup7.find("title", {"id": "pageTitle"})
    com_info2 = pd.DataFrame([blocks.text], columns = ['標題'])
    info = pd.concat([info, com_info2], axis = 0)
    #用一開始建立的info來跟後面的com_info2使用 concat 合併 axis=0 為直向合併
    info = info.reset_index(drop = True)

# %%
browser = webdriver.Chrome(executable_path = "C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe")
browser.get('https://www.facebook.com/cwgroup/posts/10157247338311930')

# %%
info
info.to_excel(r"C:\Users\Lenovo\數據分析\天下專案\title.xlsx", encoding="utf8", index = False)

# %%
info = pd.read_excel(r"C:\Users\Lenovo\數據分析\天下專案\title.xlsx")
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-14-7cf66091a17e> in <module>
#       1 info = pd.read_excel(r"C:\Users\Lenovo\數據分析\天下專案\title.xlsx")
# ----> 2 latest = pd.read_excel(r"C:\Users\Lenovo\數據分析\天下專案\2020-11-20_latest.xls")
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# --> 821         self._reader = self._engines[engine](self._io)
#     822
#     823     def __fspath__(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~\anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     155         formatting_info=formatting_info,
#     156         on_demand=on_demand,
# --> 157         ragged_rows=ragged_rows,
#     158     )
#     159     return bk
#
# ~\anaconda3\lib\site-packages\xlrd\book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      90         t1 = perf_counter()
#      91         bk.load_time_stage_1 = t1 - t0
# ---> 92         biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      93         if not biff_version:
#      94             raise XLRDError("Can't determine file's BIFF version")
#
# ~\anaconda3\lib\site-packages\xlrd\book.py in getbof(self, rqd_stream)
#    1276             bof_error('Expected BOF record; met end of file')
#    1277         if opcode not in bofcodes:
# -> 1278             bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1279         length = self.get2bytes()
#    1280         if length == MY_EOF:
#
# ~\anaconda3\lib\site-packages\xlrd\book.py in bof_error(msg)
#    1270
#    1271         def bof_error(msg):
# -> 1272             raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#    1273         savpos = self._position
#    1274         opcode = self.get2bytes()
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'<?xml ve'

# %%
month_oct = pd.merge(df, info, left_index=True, right_index=True)
month_oct
# Out:
#                                                   永久連結  \
# 0                                                  NaN
# 1    https://www.facebook.com/cwgroup/posts/1015724...
# 2    https://www.facebook.com/cwgroup/posts/1015724...
# 3    https://www.facebook.com/cwgroup/posts/1015724...
# 4    https://www.facebook.com/cwgroup/posts/1015724...
# ..                                                 ...
# 919  https://www.facebook.com/cwgroup/posts/1015718...
# 920  https://www.facebook.com/cwgroup/posts/1015718...
# 921  https://www.facebook.com/cwgroup/posts/1015718...
# 922  https://www.facebook.com/cwgroup/posts/1015718...
# 923  https://www.facebook.com/cwgroup/posts/1015718...
#
#                              Lifetime Post Total Reach  \
# 0    Lifetime: The number of people who had your Pa...
# 1                                                 7240
# 2                                                 9448
# 3                                                34823
# 4                                               109883
# ..                                                 ...
# 919                                              10317
# 920                                              13138
# 921                                              21804
# 922                                              13841
# 923                                              17345
#
#                                                     標題
# 0    天下雜誌 - 台灣超商的密度堪稱世界第一，但獲利依然良好，關鍵又在哪裡？清華講座教授暨美光講...
# 1      天下雜誌 - #Off學【巴黎不是只有浪漫，法國女人也不總是優雅】... | Facebook
# 2    天下雜誌 - ◤陳俊志：同志，讓我成為無父之人◢\n第18屆同志大遊行今天在台北登場！......
# 3    天下雜誌 - #一週圖表【不能只有台積電！台韓市值前十大企業比照表】\n　... | Fac...
# 4    天下雜誌 - #廣編企劃\n《千大企業家》百德機械謝瑞木的「第三人生」策略... | Fac...
# ..                                                 ...
# 919  天下雜誌 - 中秋節是全家團圓的時光。而對你來說，這樣的聚會是天倫之樂、還是「相愛相殺」、不...
# 920      天下雜誌 - 【藝FUN券還沒花：這是遊客心目中的必訪8熱點】... | Facebook
# 921  天下雜誌 - #廣編企劃 \n「人都需要從互動中找到存在感」—圖文創作家  我是馬克... ...
# 922  天下雜誌 - 【台灣、美國聯手對抗疫情！】#未來城市\n\n台灣能守住疫情，#科技 #AI....
# 923            天下雜誌 - 【你願意，花2000塊剪一顆頭嗎？】... | Facebook
#
# [924 rows x 3 columns]

# %%
Oct_data = pd.merge(month_oct,all_like,how = "inner")
Oct_data
# Out:
#                                                   永久連結  \
# 0    https://www.facebook.com/cwgroup/posts/1015724...
# 1    https://www.facebook.com/cwgroup/posts/1015724...
# 2    https://www.facebook.com/cwgroup/posts/1015724...
# 3    https://www.facebook.com/cwgroup/posts/1015724...
# 4    https://www.facebook.com/cwgroup/posts/1015724...
# ..                                                 ...
# 921  https://www.facebook.com/cwgroup/posts/1015718...
# 922  https://www.facebook.com/cwgroup/posts/1015718...
# 923  https://www.facebook.com/cwgroup/posts/1015718...
# 924  https://www.facebook.com/cwgroup/posts/1015718...
# 925  https://www.facebook.com/cwgroup/posts/1015718...
#
#     Lifetime Post Total Reach  \
# 0                        7240
# 1                        9448
# 2                       34823
# 3                      109883
# 4                       11631
# ..                        ...
# 921                     10317
# 922                     13138
# 923                     21804
# 924                     13841
# 925                     17345
#
#                                                     標題       已發佈  like  \
# 0      天下雜誌 - #Off學【巴黎不是只有浪漫，法國女人也不總是優雅】... | Facebook  10/30/20    11
# 1    天下雜誌 - ◤陳俊志：同志，讓我成為無父之人◢\n第18屆同志大遊行今天在台北登場！......  10/30/20    12
# 2    天下雜誌 - #一週圖表【不能只有台積電！台韓市值前十大企業比照表】\n　... | Fac...  10/30/20    63
# 3    天下雜誌 - #廣編企劃\n《千大企業家》百德機械謝瑞木的「第三人生」策略... | Fac...  10/30/20   329
# 4        天下雜誌 - 【媒體如何認清先天障礙，強化自身優勢突圍而出？】... | Facebook  10/30/20    15
# ..                                                 ...       ...   ...
# 921  天下雜誌 - 中秋節是全家團圓的時光。而對你來說，這樣的聚會是天倫之樂、還是「相愛相殺」、不...   10/1/20    11
# 922      天下雜誌 - 【藝FUN券還沒花：這是遊客心目中的必訪8熱點】... | Facebook   10/1/20    32
# 923  天下雜誌 - #廣編企劃 \n「人都需要從互動中找到存在感」—圖文創作家  我是馬克... ...   10/1/20    22
# 924  天下雜誌 - 【台灣、美國聯手對抗疫情！】#未來城市\n\n台灣能守住疫情，#科技 #AI....   10/1/20    40
# 925            天下雜誌 - 【你願意，花2000塊剪一顆頭嗎？】... | Facebook   10/1/20    24
#
#      comment  share month
# 0        NaN    2.0   NaN
# 1        NaN    5.0   NaN
# 2        2.0    7.0   NaN
# 3       16.0   49.0   NaN
# 4        1.0    2.0   NaN
# ..       ...    ...   ...
# 921      NaN    NaN    10
# 922      NaN    6.0    10
# 923      NaN    5.0    10
# 924      NaN    5.0    10
# 925      2.0    NaN    10
#
# [926 rows x 8 columns]

# %%
Oct_data.to_excel(r"C:\Users\Lenovo\數據分析\天下專案\Oct_data.xlsx", encoding="utf8", index = False)
